# %%
import os
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# configuration load
with open("config/config.yaml", "r") as config_file:
    config = yaml.safe_load(config_file)

# data test file retrieval from configuration 
file_path = config["data"]["input"]["velib_data"]
print(f"Relative path of data file: {file_path}")

# definition of a new dataframe read from local test data
if os.path.exists(file_path):
    df = pd.read_csv(file_path, sep=';', header=None)
    display(df.head(5))
else:
    print(f"CSV file does not exist at location: {file_path}")
    print("Current directory content:", os.listdir())
# Out:
# Relative path of data file: resources/input/velib-disponibilite-en-temps-reel.csv
#                     0                              1   \
# 0  Identifiant station                    Nom station
# 1                16107  Benjamin Godard - Victor Hugo
# 2                44015     Rouget de L'isle - Watteau
# 3                40001                 Hôpital Mondor
# 4                 9020             Toudouze - Clauzel
#
#                           2                       3                        4   \
# 0  Station en fonctionnement  Capacité de la station  Nombre bornettes libres
# 1                        OUI                       0                       27
# 2                        OUI                       0                       12
# 3                        OUI                       0                       23
# 4                        OUI                       0                       18
#
#                                5                             6   \
# ...
