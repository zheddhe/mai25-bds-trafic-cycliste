# %% [markdown]
# # 1. Initializations

# %% [markdown]
# ## 1.1 General imports

# %%
### data management
# import pandas as pd
# import numpy as np
# import statsmodels.api as sm

### graphical matplotlib basics
# import matplotlib.pyplot as plt
# # for jupyter notebook display management
# %matplotlib inline
# %config Completer.use_jedi = False

### graphical plotly basics
# import plotly.graph_objects as go
# import plotly.express as px
# # for jupyter notebook display management
# import plotly.io as pio
# pio.renderers.default = "notebook"

# %% [markdown]
# ## 1.2 General dataframe functions

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(f"Projet initialisé depuis : {PROJECT_ROOT}")
from smartcheck import dataframe_common as dfc
# Out:
# Projet initialisé depuis : C:\Users\remyc\PycharmProjects\avr25-mle-velib

# %% [markdown]
# # 2. Loading and Data Quality

# %% [markdown]
# ## 2.1 Loading of data sets and general exploration

# %%
df_disp_velib = dfc.load_dataset_from_config('velib_dispo_data', sep=';')
if df_disp_velib is not None:
    display(df_disp_velib.head())
    dfc.log_general_info(df_disp_velib.iloc[:,:])
# Out:
# [INFO]-[2025-05-23 14:10:31,488] File path resolved from configuration : https://drive.google.com/file/d/1kBkBYm55NrNZ55fjD2G7jvdJqIz517Qm/view?usp=drive_link.
# [INFO]-[2025-05-23 14:10:31,489] File ID extracted from URL: 1kBkBYm55NrNZ55fjD2G7jvdJqIz517Qm
#   Identifiant station                    Nom station  \
# 0               16107  Benjamin Godard - Victor Hugo
# 1               44015     Rouget de L'isle - Watteau
# 2               40001                 Hôpital Mondor
# 3                9020             Toudouze - Clauzel
# 4               13007             Le Brun - Gobelins
#
#   Station en fonctionnement  Capacité de la station  Nombre bornettes libres  \
# 0                       OUI                       0                       27
# 1                       OUI                       0                       12
# 2                       OUI                       0                       23
# 3                       OUI                       0                       18
# ...

# %%
df_cpt_velib = dfc.load_dataset_from_config('velib_comptage_data', sep=';')
if df_cpt_velib is not None:
    display(df_cpt_velib.head())
    dfc.log_general_info(df_cpt_velib.iloc[:,:])
# Out:
# [INFO]-[2025-05-23 14:10:34,614] File path resolved from configuration : https://drive.google.com/file/d/1IN7U_BkhrfPEfjCvD61sxVo_zMsKk6A9/view?usp=sharing.
# [INFO]-[2025-05-23 14:10:34,615] File ID extracted from URL: 1IN7U_BkhrfPEfjCvD61sxVo_zMsKk6A9
# [INFO]-[2025-05-23 14:10:35,177] Big file mechanism : Attempting download from confirmation URL.
#   Identifiant du compteur                     Nom du compteur  \
# 0     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 1     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 2     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 3     100003098-101003098  106 avenue Denfert Rochereau NE-SO
# 4     100003098-101003098  106 avenue Denfert Rochereau NE-SO
#
#    Identifiant du site de comptage       Nom du site de comptage  \
# 0                      100003098.0  106 avenue Denfert Rochereau
# 1                      100003098.0  106 avenue Denfert Rochereau
# ...
